# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_csv_files(csv_files):
    for csv_file in csv_files:
        df = pd.read_csv(csv_file)  # Lê o arquivo CSV e cria um DataFrame
        csv_file = csv_file[:-4]
        df.sort_values(by=['N'], inplace=True)  # Ordena o DataFrame pelo número de pontos (N
        plt.plot(df['N'], df['Tempo'], label=csv_file)  # Plota os dados do arquivo CSV

    plt.ylabel('Tempo(s)')  # Define o rótulo do eixo x
    plt.xlabel('Número de pontos')  # Define o rótulo do eixo y
    plt.title('Gráfico de Tempos')  # Define o título do gráfico
    plt.legend()  # Adiciona a legenda

    plt.show()  # Exibe o gráfico


# Lista com os nomes dos arquivos CSV
csv_files = ['Linear.csv', 'Merge.csv', 'Jarvis.csv']

plot_csv_files(csv_files)

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_csv_files(csv_files):
    for csv_file in csv_files:
        df = pd.read_csv(csv_file)  # Lê o arquivo CSV e cria um DataFrame
        csv_file = csv_file[:-4]
        df.sort_values(by=['N'], inplace=True)  # Ordena o DataFrame pelo número de pontos (N
        plt.plot(df['N'], df['Tempo'], label=csv_file)  # Plota os dados do arquivo CSV

    plt.ylabel('Tempo(s)')  # Define o rótulo do eixo x
    plt.xlabel('Número de pontos')  # Define o rótulo do eixo y
    plt.title('Gráfico de Tempos')  # Define o título do gráfico
    plt.legend()  # Adiciona a legenda

    plt.show()  # Exibe o gráfico


# Lista com os nomes dos arquivos CSV
csv_files = ['Insertion.csv', 'Merge.csv', 'Linear.csv', 'Jarvis.csv']

plot_csv_files(csv_files)
